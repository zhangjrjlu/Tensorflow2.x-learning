# %%
# !pip install -U efficientnet
# Out:
# Requirement already up-to-date: efficientnet in d:\anaconda3\envs\tensorflow2.x\lib\site-packages (1.1.0)
# Requirement already satisfied, skipping upgrade: keras-applications<=1.0.8,>=1.0.7 in d:\anaconda3\envs\tensorflow2.x\lib\site-packages (from efficientnet) (1.0.8)
# Requirement already satisfied, skipping upgrade: scikit-image in d:\anaconda3\envs\tensorflow2.x\lib\site-packages (from efficientnet) (0.17.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.1 in d:\anaconda3\envs\tensorflow2.x\lib\site-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (1.19.0)
# Requirement already satisfied, skipping upgrade: h5py in d:\anaconda3\envs\tensorflow2.x\lib\site-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (2.10.0)
# Requirement already satisfied, skipping upgrade: pillow!=7.1.0,!=7.1.1,>=4.3.0 in d:\anaconda3\envs\tensorflow2.x\lib\site-packages (from scikit-image->efficientnet) (7.2.0)
# Requirement already satisfied, skipping upgrade: imageio>=2.3.0 in d:\anaconda3\envs\tensorflow2.x\lib\site-packages (from scikit-image->efficientnet) (2.9.0)
# Requirement already satisfied, skipping upgrade: networkx>=2.0 in d:\anaconda3\envs\tensorflow2.x\lib\site-packages (from scikit-image->efficientnet) (2.4)
# Requirement already satisfied, skipping upgrade: scipy>=1.0.1 in d:\anaconda3\envs\tensorflow2.x\lib\site-packages (from scikit-image->efficientnet) (1.4.1)
# Requirement already satisfied, skipping upgrade: tifffile>=2019.7.26 in d:\anaconda3\envs\tensorflow2.x\lib\site-packages (from scikit-image->efficientnet) (2020.7.4)
# Requirement already satisfied, skipping upgrade: matplotlib!=3.0.0,>=2.0.0 in d:\anaconda3\envs\tensorflow2.x\lib\site-packages (from scikit-image->efficientnet) (3.2.2)
# Requirement already satisfied, skipping upgrade: PyWavelets>=1.1.1 in d:\anaconda3\envs\tensorflow2.x\lib\site-packages (from scikit-image->efficientnet) (1.1.1)
# Requirement already satisfied, skipping upgrade: six in d:\anaconda3\envs\tensorflow2.x\lib\site-packages (from h5py->keras-applications<=1.0.8,>=1.0.7->efficientnet) (1.15.0)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in d:\anaconda3\envs\tensorflow2.x\lib\site-packages (from networkx>=2.0->scikit-image->efficientnet) (4.4.2)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in d:\anaconda3\envs\tensorflow2.x\lib\site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet) (2.8.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in d:\anaconda3\envs\tensorflow2.x\lib\site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet) (0.10.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in d:\anaconda3\envs\tensorflow2.x\lib\site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet) (1.2.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in d:\anaconda3\envs\tensorflow2.x\lib\site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet) (2.4.7)

# %%
import numpy as np
import pandas as pd
import os
import cv2
import tensorflow as tf
import efficientnet.tfkeras as efn
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt

gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %config InlineBackend.figure_format = 'retina'
folder = 'E:/plant-pathology-2020-fgvc7'

# %%
Y = pd.read_csv(os.path.join(folder,'train.csv'))
train_id = Y['image_id']
Y = Y[Y.columns[1:]] # remove image_id column
Y = Y.values # convert to array
print(Y.shape)
# Out:
# (1821, 4)

# %%
def image_resize(size, img_id):
    '''
    resize all images to same dimensions
    amended from https://www.kaggle.com/shawon10/plant-pathology-classification-using-densenet121
    '''
    images=[]
    for i, name in enumerate(img_id):
        path=os.path.join(folder,'images',name+'.jpg')
        img=cv2.imread(path)
        image=cv2.resize(img,(size,size),interpolation=cv2.INTER_AREA)
        images.append(image)
        # print processing counter
        if i%200==0:
            print(i, 'images processed')
    return images


X = image_resize(100, train_id)
X = np.array(X)
# Out:
# 0 images processed
# 200 images processed
# 400 images processed
# 600 images processed
# 800 images processed
# 1000 images processed
# 1200 images processed
# 1400 images processed
# 1600 images processed
# 1800 images processed

# %%
X_train, X_val, Y_train, Y_val = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
aug = ImageDataGenerator(rotation_range=360, # Degree range for random rotations
                          width_shift_range=0.2, # Range for random horizontal shifts
                          height_shift_range=0.2, # Range for random vertical shifts
                          zoom_range=0.2, # Range for random zoom
                          horizontal_flip=True, # Randomly flip inputs horizontally
                          vertical_flip=True) # Randomly flip inputs vertically

train_flow = aug.flow(X_train, Y_train, batch_size=4)

# %%
def model(input_shape, classes):

    base = efn.EfficientNetB7(input_shape=input_shape, weights='imagenet', include_top=False)

    model = Sequential()
    model.add(base)
    model.add(GlobalAveragePooling2D())
    model.add(Dense(classes, activation='softmax'))
    model.compile(loss='categorical_crossentropy',
                optimizer='adam',
                metrics=['accuracy'])
    return model

# each pic has been resized to 100x100, and with 3 channels (RGB)
input_shape = (100,100,3)
classes = 4
model = model(input_shape, classes)
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# efficientnet-b7 (Model)      (None, 4, 4, 2560)        64097680
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 2560)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 10244
# =================================================================
# Total params: 64,107,924
# Trainable params: 63,797,204
# Non-trainable params: 310,720
# _________________________________________________________________

# %%
# for every epoch, the total original images will be augmented randomly
model.fit_generator(train_flow,
                    steps_per_epoch=32,
                    epochs=5,
                    verbose=1,
                    validation_data=(X_val, Y_val),
                    )
# Out:
# Epoch 1/5
# 32/32 [==============================] - 56s 2s/step - loss: 1.9829 - accuracy: 0.2734 - val_loss: 1.5010 - val_accuracy: 0.2329
# Epoch 2/5
# 32/32 [==============================] - 55s 2s/step - loss: 1.9105 - accuracy: 0.2734 - val_loss: 7.0576 - val_accuracy: 0.2740
# Epoch 3/5
# 32/32 [==============================] - 55s 2s/step - loss: 1.4590 - accuracy: 0.3203 - val_loss: 3.0305 - val_accuracy: 0.3397
# Epoch 4/5
# 32/32 [==============================] - 54s 2s/step - loss: 1.4421 - accuracy: 0.3438 - val_loss: 1.4066 - val_accuracy: 0.2740
# Epoch 5/5
# 32/32 [==============================] - 54s 2s/step - loss: 1.3708 - accuracy: 0.3125 - val_loss: 1.3819 - val_accuracy: 0.4384

# %%
def plot_validate(model, loss_acc):
    '''
    Plot model accuracy or loss for both train and test validation per epoch
    model : fitted model
    loss_acc : input 'loss' or 'acc' to plot respective graph
    '''
    history = model.history.history

    if loss_acc == 'loss':
        axis_title = 'loss'
        title = 'Loss'
        epoch = len(history['loss'])
    elif loss_acc == 'acc':
        axis_title = 'accuracy'
        title = 'Accuracy'
        epoch = len(history['loss'])

    plt.figure(figsize=(15,4))
    plt.plot(history[axis_title])
    plt.plot(history['val_' + axis_title])
    plt.title('Model ' + title)
    plt.ylabel(title)
    plt.xlabel('Epoch')

    plt.grid(b=True, which='major')
    plt.minorticks_on()
    plt.grid(b=True, which='minor', alpha=0.2)

    plt.legend(['Train', 'Test'])
    plt.show()


plot_validate(model, 'acc')
plot_validate(model, 'loss')
